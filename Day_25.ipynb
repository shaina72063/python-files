# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("countries-of-the-world.csv")
data.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    object
#  5   Coastline (coast/area ratio)        227 non-null    object
#  6   Net migration                       224 non-null    object
#  7   Infant mortality (per 1000 births)  224 non-null    object
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    object
#  10  Phones (per 1000)                   223 non-null    object
# ...

# %%
data.isna().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
data['Literacy (%)'] = data['Literacy (%)'].fillna(0)

# %%
data.isna().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                           0
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %% [markdown]
# #  make a new dataframe have columns country, pop, area,gdp,literacy

# %%
df= data[['Country','Population','Area (sq. mi.)','GDP ($ per capita)','Literacy (%)']]
df.head()
# Out:
#            Country  Population  Area (sq. mi.)  GDP ($ per capita)  \
# 0     Afghanistan     31056997          647500               700.0
# 1         Albania      3581655           28748              4500.0
# 2         Algeria     32930091         2381740              6000.0
# 3  American Samoa        57794             199              8000.0
# 4         Andorra        71201             468             19000.0
#
#   Literacy (%)
# 0         36,0
# 1         86,5
# 2         70,0
# 3         97,0
# 4        100,0

# %%
n_c = df[df['Country'].isin(['Afghanistan','Albania'])]
n_c
# Out:
# Empty DataFrame
# Columns: [Country, Population, Area (sq. mi.), GDP ($ per capita), Literacy (%)]
# Index: []

# %%
student ={
    "rollno":[1001,1002,1003,1004,1005],
    "name":['Kajal','Shaina','Khushi','Priyanka','Neha'],
    "address":['Panipat','Delhi','Mumbai','Chandigarh','Rohtak']
}
data = pd.DataFrame(student)
data
# Out:
#    rollno      name     address
# 0    1001     Kajal     Panipat
# 1    1002    Shaina       Delhi
# 2    1003    Khushi      Mumbai
# 3    1004  Priyanka  Chandigarh
# 4    1005      Neha      Rohtak

# %%
df1 = data["rollno"].isin([1001,1004,1002])
df1
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# Name: rollno, dtype: bool

# %%
name_list = ["Kajal","Shaina","Neha"]
df2 = data[data["name"].isin(name_list)]
df2
# Out:
#    rollno    name  address
# 0    1001   Kajal  Panipat
# 1    1002  Shaina    Delhi
# 4    1005    Neha   Rohtak
