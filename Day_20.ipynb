# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    'iid':[1,2,3],
    'cid':[2,4,8],
    'invoice_date':['2024-07-01','2024-07-04','2024-07-03'],
    'total':[1.8,2.5,6.5]
}

# %%
inv_jan = pd.DataFrame(dict1)
inv_jan
# Out:
#    iid  cid invoice_date  total
# 0    1    2   2024-07-01    1.8
# 1    2    4   2024-07-04    2.5
# 2    3    8   2024-07-03    6.5

# %%
dict2 = {
    'iid':[7,8,9],
    'cid':[38,40,42],
    'invoice_date':['2024-07-01','2024-07-02','2024-07-01'],
    'total':[1.98,2.56,3.6]
}

# %%
inv_feb = pd.DataFrame(dict2)
inv_feb
# Out:
#    iid  cid invoice_date  total
# 0    7   38   2024-07-01   1.98
# 1    8   40   2024-07-02   2.56
# 2    9   42   2024-07-01   3.60

# %%
dict3 = {
    'iid':[10,11,12],
    'cid':[5,61,13],
    'invoice_date':['2024-06-01','2024-03-02','2024-05-06'],
    'total':[3.2,5.3,4.6]
}

# %%
inv_march = pd.DataFrame(dict3)
inv_march
# Out:
#    iid  cid invoice_date  total
# 0   10    5   2024-06-01    3.2
# 1   11   61   2024-03-02    5.3
# 2   12   13   2024-05-06    4.6

# %%
pd.concat([inv_jan,inv_feb,inv_march],keys = ['Jan','Feb','March']) # ignore_index = True
# Out:
#          iid  cid invoice_date  total
# Jan   0    1    2   2024-07-01   1.80
#       1    2    4   2024-07-04   2.50
#       2    3    8   2024-07-03   6.50
# Feb   0    7   38   2024-07-01   1.98
#       1    8   40   2024-07-02   2.56
#       2    9   42   2024-07-01   3.60
# March 0   10    5   2024-06-01   3.20
#       1   11   61   2024-03-02   5.30
#       2   12   13   2024-05-06   4.60

# %%
# joining dataframe with different columns

# %%
dict3 = {
    'iid':[7,8,9],
    'cid':[38,40,42],
    'invoice_date':['2024-07-01','2024-07-02','2024-07-01'],
    'total':[1.98,2.56,3.6],
    'bill_city':['panipat','delhi','palwal']
}

# %%
inv_feb = pd.DataFrame(dict3)
inv_feb
# Out:
#    iid  cid invoice_date  total bill_city
# 0    7   38   2024-07-01   1.98   panipat
# 1    8   40   2024-07-02   2.56     delhi
# 2    9   42   2024-07-01   3.60    palwal

# %%
pd.concat([inv_jan,inv_feb],sort = True)
# Out:
#   bill_city  cid  iid invoice_date  total
# 0       NaN    2    1   2024-07-01   1.80
# 1       NaN    4    2   2024-07-04   2.50
# 2       NaN    8    3   2024-07-03   6.50
# 0   panipat   38    7   2024-07-01   1.98
# 1     delhi   40    8   2024-07-02   2.56
# 2    palwal   42    9   2024-07-01   3.60

# %%
pd.concat([inv_jan,inv_feb],join = 'inner')
# Out:
#    iid  cid invoice_date  total
# 0    1    2   2024-07-01   1.80
# 1    2    4   2024-07-04   2.50
# 2    3    8   2024-07-03   6.50
# 0    7   38   2024-07-01   1.98
# 1    8   40   2024-07-02   2.56
# 2    9   42   2024-07-01   3.60

# %%
tra = {
    'tid':[2,3,4],
    'name':['Balls','Fast','Bat'],
    'aid':[2,3,4],
    'mtid':[2,2,2],
    'gid':[1,1,1],
    'u_price':[0.99,0.99,0.99]
}

# %%
tracks = pd.DataFrame(tra)
tracks
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 tracks = pd.DataFrame(tra)
#       2 tracks
#
# NameError: name 'pd' is not defined

# %%
spe = {
    'tid':[2,3],
    'milliseconds':[3456,2345],
    'bytes':[5510424,3990994]
}

# %%
specs = pd.DataFrame(spe)
specs
# Out:
#    tid  milliseconds    bytes
# 0    2          3456  5510424
# 1    3          2345  3990994

# %%
tracks.merge(specs, on ='tid',validate = 'one_to_one')
# Out:
#    tid   name  aid  mtid  gid  u_price  milliseconds    bytes
# 0    2  Balls    2     2    1     0.99          3456  5510424
# 1    3   Fast    3     2    1     0.99          2345  3990994
